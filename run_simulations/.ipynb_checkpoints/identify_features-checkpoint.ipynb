# %%
import json

# %%
top_columns = [
    hh_t10_BED &amp; MATTRESS
    hh_f12_ELECTRICITY
    hh_f41_Flush to septic tank
    hh_f12_CHARCOAL
    hh_t03_It was less than adequate for household needs
    hh_t19_NO
    hh_t04_It was more than adequate for household needs
    hh_f01_OWNED
    hh_h02d
    hh_g09_NO
    hh_h01_YES
    hh_f41_4_NO
    hh_f41_Flush to pit latrine
    hh_f41_Pit latrine with slab
    hh_x02_2018/19
    dist_auction
    region_Central
    hh_h04_YES
    hh_h03a
    hh_t08_ONLY JUST MEETS YOUR EXPENSES
    hh_f01_BEING PURCHASED
    hh_t10_MAT (GRASS) ON FLOOR
    district_Blantyre City
    hh_f41_1_Yes
    af_bio_8_x
    cropshare
    hh_x04
    hh_t08_IS REALLY NOT SUFFICIENT, SO YOU NEED TO BORROW TO MEET EXPENSES
    hh_t12_BLANKET &amp; SHEETS
    hh_f11_CANDLES

# %%
inverse_one_hot_map = json.load(open( "/Users/leo/Documents/gpl/eop/data/malawi/inverse_one_hot_map.json", 'r') )

# %%
inverse_one_hot_map
# Out:
# {'ag_b101_YES': ['ag_b101', 'YES'],
#  'ag_i101b_YES': ['ag_i101b', 'YES'],
#  'ag_s01_YES': ['ag_s01', 'YES'],
#  'area_Rural Centre': ['area', 'Rural Centre'],
#  'area_Rural North': ['area', 'Rural North'],
#  'area_Rural South': ['area', 'Rural South'],
#  'area_Urban': ['area', 'Urban'],
#  'district_Balaka': ['district', 'Balaka'],
#  'district_Blantyre': ['district', 'Blantyre'],
#  'district_Blantyre City': ['district', 'Blantyre City'],
#  'district_Chikwawa': ['district', 'Chikwawa'],
#  'district_Chiradzulu': ['district', 'Chiradzulu'],
#  'district_Chitipa': ['district', 'Chitipa'],
#  'district_Dedza': ['district', 'Dedza'],
#  'district_Dowa': ['district', 'Dowa'],
#  'district_Karonga': ['district', 'Karonga'],
#  'district_Kasungu': ['district', 'Kasungu'],
#  'district_Likoma': ['district', 'Likoma'],
#  'district_Lilongwe': ['district', 'Lilongwe'],
#  'district_Lilongwe City': ['district', 'Lilongwe City'],
#  'district_Machinga': ['district', 'Machinga'],
# ...
