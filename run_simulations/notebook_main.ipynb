# %%
import helpers
import run
from pathlib import Path
import importlib

import pandas as pd

# %%
features = pd.read_csv('../select_predictors/2016/selected_columns_no_mosaiks.csv')

# %%
importlib.reload(helpers)
importlib.reload(run)
# Out:
# <module 'run' from '/home/selker/eop/eop/run_simulations/run.py'>

# %%
# %%time
run.malawi_runs(
    features.Covariate.values,
    extra_run_labels={'features': '4/18 pmt', 'data_year': '2016'}
)
# Out:
# KNOTS:[-3.19668199 -3.19668199 -3.19668199 -3.19668199 -1.17361046 -0.81842695
#  -0.29826652  0.17892435 10.85791074 10.85791074 10.85791074 10.85791074]
# KNOTS:[-3.19668199 -3.19668199 -3.19668199 -3.19668199 -1.17361046 -0.81842695
#  -0.29826652  0.17892435 10.85791074 10.85791074 10.85791074 10.85791074]
# KNOTS:[-3.19668199 -3.19668199 -3.19668199 -3.19668199 -1.17361046 -0.81842695
#  -0.29826652  0.17892435 10.85791074 10.85791074 10.85791074 10.85791074]
# KNOTS:[-3.19668199 -3.19668199 -3.19668199 -3.19668199 -1.17361046 -0.81842695
#  -0.29826652  0.17892435 10.85791074 10.85791074 10.85791074 10.85791074]
# Fitting conditional densities vs glm spline method...Fitting conditional densities vs glm spline method...
# Fitting conditional densities vs glm spline method...
#   0%|                                                            | 0/300 [00:00<?, ?it/s]
# Fitting conditional densities vs glm spline method...
# ...
