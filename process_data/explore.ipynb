# %%
import geopandas as gpd
import pandas as pd

# %%
namibia = pd.read_parquet(
    '/data/eop/country_data/NAM/cleaned/full.parquet'
)

# %%
namibia.region_constituency
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /data/tmp/ipykernel_3389561/2287473417.py in ?()
# ----> 1 namibia.region_constituency
#
# ~/.conda/envs/leo_base/lib/python3.9/site-packages/pandas/core/generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'region_constituency'

# %%
civ = gpd.read_file('/data/eop/geo/shapefiles/CIV/geoBoundaries-CIV-ADM3.geojson')

# %%
civ
# Out:
#           shapeName shapeISO                  shapeID shapeGroup shapeType  \
# 0        Abengourou           97208781B79507402496729        CIV      ADM3
# 1           Abidjan           97208781B76519329112770        CIV      ADM3
# 2            Abigui           97208781B41403758936369        CIV      ADM3
# 3           Aboisso           97208781B20708403365114        CIV      ADM3
# 4    Aboisso-Como̩           97208781B41857222319985        CIV      ADM3
# ..              ...      ...                      ...        ...       ...
# 505          Zonneu            97208781B1715413200145        CIV      ADM3
# 506             Zou           97208781B81251785358251        CIV      ADM3
# 507   Zouan Hounien           97208781B27222280957683        CIV      ADM3
# 508      Zoukougbeu           97208781B31211302068608        CIV      ADM3
# 509       Zu̩noula           97208781B43915365556699        CIV      ADM3
#
#                                               geometry
# ...
